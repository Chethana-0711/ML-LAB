# %% [markdown]
# <a href="https://colab.research.google.com/github/Chethana-0711/ML-LAB/blob/main/K-means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================
# K-MEANS COMPLETE PROGRAM
# =========================

# 1. Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans

# 2. Load Dataset (Iris)
data = load_iris()
X = data.data

# 3. Elbow Method to find optimal K
inertia = []
K_range = range(1, 10)

for k in K_range:
    km = KMeans(n_clusters=k, random_state=0)
    km.fit(X)
    inertia.append(km.inertia_)

# Plot Elbow Graph
plt.figure()
plt.plot(K_range, inertia, marker='o')
plt.title("Elbow Method to Find Optimal K")
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Inertia")
plt.show()

# 4. Apply K-Means with K=3
kmeans = KMeans(n_clusters=3, random_state=0)
y_kmeans = kmeans.fit_predict(X)

# 5. Print Cluster Centers
print("Cluster Centers:\n", kmeans.cluster_centers_)

# 6. Visualize Clusters (using first 2 features)
plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, cmap='viridis')

# Plot Centroids
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200)

plt.title("K-Means Clustering (Iris Dataset)")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
# Out:
# Cluster Centers:
#  [[5.88360656 2.74098361 4.38852459 1.43442623]
#  [5.006      3.428      1.462      0.246     ]
#  [6.85384615 3.07692308 5.71538462 2.05384615]]
